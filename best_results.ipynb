# %%
from data.dataset_handler import DatasetHandler

handler = DatasetHandler()

df = handler.ler_dataset("data/treino_sinais_vitais_com_label.csv")
df = handler.remover_colunas(df, ["s1","s2", "gravidade", "vitima"])
X,y = handler.extrair_features_target(df,"classe")

from decision_tree import decision_tree
from decision_tree.decision_tree import TreeNode

#Defining hyperparameters
param_grid = {'min_samples_split': [4], 
              'max_depth': [16], 
              'seed': [5]}
#252 combinações
#TOTAL: 1008 combinações


#Cross validation to find the best hyperparameters
for i in range(5):
    #Initialization of the model
    tree = TreeNode(verbose=False)
    decision_tree.crossvalidation(X, y, tree, 2, param_grid, seed=12)
for i in range(5):
    #Initialization of the model
    tree = TreeNode(verbose=False)
    decision_tree.crossvalidation(X, y, tree, 5, param_grid, seed=12)
for i in range(5):
    #Initialization of the model
    tree = TreeNode(verbose=False)
    decision_tree.crossvalidation(X, y, tree, 10, param_grid, seed=12)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 24
#      21 for i in range(5):
#      22     #Initialization of the model
#      23     tree = TreeNode(verbose=False)
# ---> 24     decision_tree.crossvalidation(X, y, tree, 2, param_grid, seed=12)
#      25 for i in range(5):
#      26     #Initialization of the model
#      27     tree = TreeNode(verbose=False)
#
# File ~/Documents/UTFPR/2024.1/Sistemas inteligentes/aprendizado-maquina-SI/decision_tree/decision_tree.py:275, in crossvalidation(X, y, model, n_folds, params, seed, q, save)
#     273 model.set_params(params[j])
#     274 #Train the model with the fold
# --> 275 model.fit(X.loc[folds[k]], y.loc[folds[k]])
#     276 #Predict using the first fold as test set
#     277 prediction = X.loc[folds[0]].apply(lambda row : model.predict(row), axis = 1)
#
# File ~/Documents/UTFPR/2024.1/Sistemas inteligentes/aprendizado-maquina-SI/decision_tree/decision_tree.py:39, in TreeNode.fit(self, X, y)
#      37 def fit(self, X, y):
#      38     if (self.validate_data(X, y)):
# ---> 39         self.recursiveGenerateTree(X, y, 0)
#
# File ~/Documents/UTFPR/2024.1/Sistemas inteligentes/aprendizado-maquina-SI/decision_tree/decision_tree.py:70, in TreeNode.recursiveGenerateTree(self, sample_data, sample_target, current_depth)
#      67             self.decision = self.getMajClass(sample_target)
#      68         else:
#      69 #Call the function to select best_attribute to split
# ---> 70             best_attribute,best_threshold,splitter = self.splitAttribute(sample_data,
#      71                                                                          sample_target)
#      72             self.children = {} #Initializing a dictionary with the children nodes
#      73             self.split_feat_name = best_attribute  #Name of the feature
#
# File ~/Documents/UTFPR/2024.1/Sistemas inteligentes/aprendizado-maquina-SI/decision_tree/decision_tree.py:151, in TreeNode.splitAttribute(self, sample_data, sample_target)
#     144 classification.replace({False: "less", True: "greater"}, inplace=True)
#     145 # classification[classification] = 'greater'
#     146 # classification[classification == False] = 'less'
#     147 # print(classification)
#     148
#     149 # #Calculate the information gain using previous variable \
#     150 # (now categorical)
# --> 151 aig = self.compute_info_gain(classification, sample_target)
#     152 #If the information gain is more than the previous one, store
#     153 if aig >= info_gain_max:
#
# File ~/Documents/UTFPR/2024.1/Sistemas inteligentes/aprendizado-maquina-SI/decision_tree/decision_tree.py:190, in TreeNode.compute_info_gain(self, sample_attribute, sample_target)
#     187 for v, fr in values.items():
#     188     #Calculate the entropy for sample target corresponding to the class
#     189     index = sample_attribute==v
# --> 190     sub_ent = self.compute_entropy(sample_target[index])
#     191     #Weighted sum of the entropies
#     192     split_ent += fr * sub_ent
#
# KeyboardInterrupt:

# %%
from data.dataset_handler import DatasetHandler

handler = DatasetHandler()

df = handler.ler_dataset("data/treino_sinais_vitais_com_label.csv")
df = handler.remover_colunas(df, ["s1","s2", "gravidade", "vitima"])
X,y = handler.extrair_features_target(df,"classe")

from neural_network.neural_network import NeuralNetwork
from neural_network import neural_network

#Defining hyperparameters
param_grid = {
    'activation': ['logistic'],
    'batch_size': [100], #int
    'hidden_layer_sizes': [
        (30, 30, 30)
                           ], 
    'max_iter': [1000], #num epocas
    'learning_rate_init': [0.005] 
    }
# Total combinações: 4*5*9*5*5 = 4500

#Normalização para tanh
X = handler.normalizar_dados((-0.9, 0.9), X)
#Apenas muda o parâmetro da função de ativação
param_grid['activation'] = ['tanh']
#Initialization of the model
neunet = NeuralNetwork()
#Cross validation to find the best hyperparameters
for i in range(5):
    neural_network.crossvalidation(X, y, neunet, 2, param_grid, seed=12)
for i in range(5):
    neural_network.crossvalidation(X, y, neunet, 5, param_grid, seed=12)
for i in range(5):
    neural_network.crossvalidation(X, y, neunet, 10, param_grid, seed=12)
# Out:
# Parameters: {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.8893333333333333
# Best hyperparameters:
# {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.8893333333333333
# Tempo de execução: 0.397 s
# Parameters: {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.884
# Best hyperparameters:
# {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.884
# Tempo de execução: 0.747 s
# Parameters: {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.896
# Best hyperparameters:
# {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.896
# Tempo de execução: 0.985 s
# Parameters: {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.912
# Best hyperparameters:
# {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.912
# Tempo de execução: 0.985 s
# Parameters: {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.8906666666666667
# Best hyperparameters:
# {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.8906666666666667
# Tempo de execução: 0.67 s
# Parameters: {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.8533333333333334
# Best hyperparameters:
# {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.8533333333333334
# Tempo de execução: 2.638 s
# Parameters: {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.8558333333333333
# Best hyperparameters:
# {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.8558333333333333
# Tempo de execução: 2.198 s
# Parameters: {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.8583333333333333
# Best hyperparameters:
# {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.8583333333333333
# Tempo de execução: 2.223 s
# Parameters: {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.85
# Best hyperparameters:
# {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.85
# Tempo de execução: 2.315 s
# Parameters: {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.8516666666666667
# Best hyperparameters:
# {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.8516666666666667
# Tempo de execução: 2.298 s
# Parameters: {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.7792592592592593
# Best hyperparameters:
# {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.7792592592592593
# Tempo de execução: 3.968 s
# Parameters: {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.7814814814814814
# Best hyperparameters:
# {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.7814814814814814
# Tempo de execução: 3.819 s
# Parameters: {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.7844444444444445
# Best hyperparameters:
# {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.7844444444444445
# Tempo de execução: 3.975 s
# Parameters: {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.7755555555555556
# Best hyperparameters:
# {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.7755555555555556
# Tempo de execução: 3.688 s
# Parameters: {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.7799999999999999
# Best hyperparameters:
# {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.7799999999999999
# Tempo de execução: 3.634 s

# %%
from data.dataset_handler import DatasetHandler

handler = DatasetHandler()

df = handler.ler_dataset("data/treino_sinais_vitais_com_label.csv")
df = handler.remover_colunas(df, ["s1","s2", "gravidade", "vitima"])
X,y = handler.extrair_features_target(df,"classe")

from neural_network.neural_network import NeuralNetwork
from neural_network import neural_network

#Defining hyperparameters
param_grid = {
    'activation': ['logistic'],
    'batch_size': [100], #int
    'hidden_layer_sizes': [
        (30, 30, 30)
                           ], 
    'max_iter': [1000], #num epocas
    'learning_rate_init': [0.005] 
    }
# Total combinações: 4*5*9*5*5 = 4500

#Normalização para tanh
X = handler.normalizar_dados((-0.9, 0.9), X)
#Apenas muda o parâmetro da função de ativação
param_grid['activation'] = ['tanh']
#Initialization of the model

neunet = NeuralNetwork()

neural_network.crossvalidation(X, y, neunet, 5, param_grid, seed=12, conf_matrix=True)
# Out:
# Parameters: {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.8574999999999999
# Best hyperparameters:
# {'activation': 'tanh', 'batch_size': 100, 'hidden_layer_sizes': (30, 30, 30), 'max_iter': 1000, 'learning_rate_init': 0.005}, Accuracy: 0.8574999999999999
# Tempo de execução: 1.473 s

# %%
from data.dataset_handler import DatasetHandler

handler = DatasetHandler()

df = handler.ler_dataset("data/treino_sinais_vitais_com_label.csv")
df = handler.remover_colunas(df, ["s1","s2", "gravidade", "vitima"])
X,y = handler.extrair_features_target(df,"classe")

from decision_tree import decision_tree
from decision_tree.decision_tree import TreeNode

#Defining hyperparameters
param_grid = {'min_samples_split': [4], 
              'max_depth': [16], 
              'seed': [5]}
#252 combinações
#TOTAL: 1008 combinações

#Initialization of the model
tree = TreeNode(verbose=False)
decision_tree.crossvalidation(X, y, tree, 5, param_grid, seed=12, conf_matrix=True)
# Out:
# Parameters: {'min_samples_split': 4, 'max_depth': 16, 'seed': 5}, Accuracy: 0.8208333333333334
# Best hyperparameters:
# {'min_samples_split': 4, 'max_depth': 16, 'seed': 5}, Accuracy: 0.8208333333333334
